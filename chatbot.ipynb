# %%
import os
from dotenv import load_dotenv
load_dotenv()
groq_api_key=os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama-3.3-70b-versatile",
    groq_api_key=groq_api_key
)

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="Hi,My name is Manas.")])
# Out:
# AIMessage(content="Hello Manas, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 43, 'total_tokens': 70, 'completion_time': 0.045622266, 'completion_tokens_details': None, 'prompt_time': 0.001190972, 'prompt_tokens_details': None, 'queue_time': 0.051903639, 'total_time': 0.046813238}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f3993-8138-7312-843d-130be7b266fe-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 27, 'total_tokens': 70})

# %%
from langchain_core.messages import HumanMessage, AIMessage

response = model.invoke([
    HumanMessage(content="Hi, My name is Manas."),
    AIMessage(content="Hi Manas, nice to meet you! How can I assist you today?"),
    HumanMessage(content="What is my name?")
])

print(response.content)
# Out:
# Your name is Manas.

# %%
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

store={}
def get_session_history(session_id:str)->BaseChatMessageHistory:
    if session_id not in store:
        store[session_id]=ChatMessageHistory()
        return store[session_id]
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_19840\3650044273.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.chat_message_histories import ChatMessageHistory

# %%
with_message_history=RunnableWithMessageHistory(model,get_session_history)
# Out:
# c:\Users\gupta\OneDrive\Documents\chatbot\chatbot1env\Lib\site-packages\IPython\core\interactiveshell.py:3748: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
config={"configurable":{"session_id":"chat1"}}

# %%
with_message_history.invoke(
[HumanMessage(content="Hi, My name is Manas.")],
config=config
)
# Out:
# AIMessage(content="Hello Manas, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 43, 'total_tokens': 70, 'completion_time': 0.035942592, 'completion_tokens_details': None, 'prompt_time': 0.003705549, 'prompt_tokens_details': None, 'queue_time': 0.161621521, 'total_time': 0.039648141}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f402c-bc92-7aa0-a019-eca565728670-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 43, 'output_tokens': 27, 'total_tokens': 70})

# %%
##change the config
config1={"configurable":{"session_id":"chat1"}}
response=with_message_history.invoke(
[HumanMessage(content="What is my name?")],
config=config1
)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    MessagesPlaceholder(variable_name="messages"),
])

chain = prompt | model

# %%
chain.invoke({"messages":[HumanMessage(content="Hi my name is Manas.")]})
# Out:
# AIMessage(content="Hello Manas, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 48, 'total_tokens': 75, 'completion_time': 0.044602517, 'completion_tokens_details': None, 'prompt_time': 0.002205242, 'prompt_tokens_details': None, 'queue_time': 0.052816837, 'total_time': 0.046807759}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f4bf9-1afd-7cc2-822b-de92e177a856-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 27, 'total_tokens': 75})

# %%
with_messasge_history=RunnableWithMessageHistory(chain,get_session_history)
# Out:
# c:\Users\gupta\OneDrive\Documents\chatbot\chatbot1env\Lib\site-packages\IPython\core\interactiveshell.py:3748: LangChainDeprecationWarning: RunnableWithMessageHistory is deprecated. Use LangGraph's built-in persistence instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
